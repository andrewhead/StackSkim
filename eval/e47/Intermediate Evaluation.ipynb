# %%
from csv import DictReader
import random
import pandas as pd
from pandas import ExcelWriter
import numpy as np
import os.path
from IPython.display import display

# %%
from evaluate import RegexAffinityEvaluator, CssAffinityEvaluator

# %% [markdown]
# # Load Examples

# %%
REGEX_VALIDATION_FILENAME = 'regex_validation_20.csv'

link_texts = {}

with open(REGEX_VALIDATION_FILENAME) as regex_val_file:
    
    for line in regex_val_file.readlines():
        tokens = line.strip().split(',,,')
        link = tokens[3]
        text = tokens[-1]
        
        if not link in link_texts.keys():
            link_texts[link] = []
        link_texts[link].append(text)

# %% [markdown]
# Pick a random regular expression from each regex page

# %%
random.seed(1891014916634710808)

regex_examples = []
for link, texts in link_texts.items():
    regex_examples.append(random.choice(texts))

# %% [markdown]
# CSS examples have already been selected ahead of time in E45 by randomly selecting one properly detected selector from each page where at least one CSS selector was properly detected

# %%
css_examples = [
    '#infolist',
    '#message',
    '#other',
    '#frameDemo',
    '#txt',
    'div:last',
    'iframe[name=iframeTarget]',
    '#result',
    '.window',
    '#my-element',
    'div.foo',
    '#birthday',
    '#input',
    '.myeditable',
    'select.form-control',
    '#nav a',
    '#my-div img',
    '#followercnt',
    '.footable',
    '#submit4',
]

# %% [markdown]
# # Arbiter Function

# %%
def decide(css_score, regex_score):
    return "Regex" if regex_score > css_score else "CSS selector" if css_score > regex_score else "Tie"

# %% [markdown]
# # Predict Language of Strings

# %%
regex_evaluator = RegexAffinityEvaluator()
css_evaluator = CssAffinityEvaluator()

# %%
def display_scores(examples, language):
    scores = []
    for example in examples:
        css_score = round(css_evaluator.evaluate(example), 2)
        regex_score = round(regex_evaluator.evaluate(example), 2)
        scores.append([
            example,
            language,
            decide(css_score, regex_score),
            css_score,
            regex_score,
        ])
    score_frame = pd.DataFrame(scores, columns=[
        "Text",
        "Expected Language",
        "Predicted Language",
        "CSS Affinity",
        "Regex Affinity",    
    ])
    display(score_frame)
    return score_frame

# %% [markdown]
# Initialize writer for dumping data to Excel file, for post-processing

# %%
excel_writer = ExcelWriter(os.path.join('output', 'affinities.xlsx'))
excel_writer_long = ExcelWriter(os.path.join('output', 'affinities_long.xlsx'))
rows_written = 0
long_rows_written = 0

# %%
def reshape_dataframe(df):
    return pd.melt(df, id_vars=[
        "Text",
        "Expected Language",
        "Predicted Language"
    ], var_name="Evaluator", value_name="Affinity")

# %%
def write_scores(df):
    
    global rows_written
    global long_rows_written

    df.to_excel(excel_writer, startrow=rows_written, header=False, index=False)
    excel_writer.save()
    rows_written += len(df)
    
    df_long = reshape_dataframe(df)
    df_long.to_excel(excel_writer_long, startrow=long_rows_written, header=False, index=False)
    excel_writer_long.save()
    long_rows_written += len(df_long)

# %% [markdown]
# ## CSS Selectors

# %%
css_frame = display_scores(css_examples, "CSS selector")
write_scores(css_frame)
# Out:
#                          Text Expected Language Predicted Language  \
# 0                   #infolist      CSS selector       CSS selector
# 1                    #message      CSS selector       CSS selector
# 2                      #other      CSS selector       CSS selector
# 3                  #frameDemo      CSS selector       CSS selector
# 4                        #txt      CSS selector       CSS selector
# 5                    div:last      CSS selector       CSS selector
# 6   iframe[name=iframeTarget]      CSS selector       CSS selector
# 7                     #result      CSS selector       CSS selector
# 8                     .window      CSS selector       CSS selector
# 9                 #my-element      CSS selector       CSS selector
# 10                    div.foo      CSS selector       CSS selector
# 11                  #birthday      CSS selector       CSS selector
# 12                     #input      CSS selector       CSS selector
# 13                .myeditable      CSS selector       CSS selector
# 14        select.form-control      CSS selector       CSS selector
# 15                     #nav a      CSS selector       CSS selector
# 16                #my-div img      CSS selector       CSS selector
# 17               #followercnt      CSS selector       CSS selector
# 18                  .footable      CSS selector       CSS selector
# 19                   #submit4      CSS selector       CSS selector
#
#     CSS Affinity  Regex Affinity
# 0           1.00            0.00
# 1           1.00            0.00
# 2           1.00            0.00
# 3           1.00            0.00
# 4           1.00            0.00
# 5           0.50            0.00
# 6           0.75            0.14
# 7           1.00            0.00
# 8           1.00            0.14
# 9           1.00            0.00
# 10          0.75            0.14
# 11          1.00            0.00
# 12          1.00            0.00
# 13          1.00            0.09
# 14          0.75            0.05
# 15          0.75            0.00
# 16          0.75            0.00
# 17          1.00            0.00
# 18          1.00            0.11
# 19          1.00            0.00

# %% [markdown]
# ## Regular expressions

# %%
regex_frame = display_scores(regex_examples, "Regex")
write_scores(regex_frame)
# Out:
#                                                  Text Expected Language  \
# 0           <username><!\[CDATA\[name\]\]></username>             Regex
# 1                        (?<=finalNumber=")(.*?)(?=")             Regex
# 2                                              search             Regex
# 3   "^[_A-Za-z0-9-\\+]+(\\.[_A-Za-z0-9-]+)*@" + "[...             Regex
# 4                                           (..)_(..)             Regex
# 5                     ^[A-Z]{3,9}\ /index\.php\ HTTP/             Regex
# 6    (<b>) #match opening <b> tag (.*?) #match any...             Regex
# 7                                                 \\s             Regex
# 8                                           ^([^/]+)$             Regex
# 9                                        [^a-zA-Z0-9]             Regex
# 10                                       ^index\.php$             Regex
# 11                                     blue|house|car             Regex
# 12                                     <b>([^<]*)</b>             Regex
# 13                                               xmas             Regex
# 14                                     .*\([0-9]*\).*             Regex
# 15                                        ^old\.html$             Regex
# 16  ^([\w-\.]+@(?!gmail.com)(?!yahoo.com)(?!hotmai...             Regex
# 17                                           \|(.*)\|             Regex
# 18                                          [][${}\\]             Regex
# 19                                        \(\/[^:]*\)             Regex
#
#    Predicted Language  CSS Affinity  Regex Affinity
# 0                 Tie             0            0.00
# 1               Regex             0            0.22
# 2                 Tie             0            0.00
# 3               Regex             0            0.57
# 4               Regex             0            0.86
# 5               Regex             0            0.11
# 6               Regex             0            0.05
# 7                 Tie             0            0.00
# 8               Regex             0            1.00
# 9               Regex             0            1.00
# 10              Regex             0            0.18
# 11                Tie             0            0.00
# 12              Regex             0            0.22
# 13                Tie             0            0.00
# 14              Regex             0            0.60
# 15              Regex             0            0.20
# 16              Regex             0            0.32
# 17              Regex             0            0.50
# 18              Regex             0            1.00
# 19              Regex             0            0.25

# %% [markdown]
# # Cleanup

# %%
excel_writer.close()
excel_writer_long.close()
