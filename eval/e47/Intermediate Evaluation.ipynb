# %%
from csv import DictReader
import random
import pandas as pd
import numpy as np
from IPython.display import display

# %%
from evaluate import RegexAffinityEvaluator, CssAffinityEvaluator

# %% [markdown]
# # Load Examples

# %%
REGEX_VALIDATION_FILENAME = 'regex_validation_20.csv'

link_texts = {}

with open(REGEX_VALIDATION_FILENAME) as regex_val_file:
    
    for line in regex_val_file.readlines():
        tokens = line.strip().split(',,,')
        link = tokens[3]
        text = tokens[-1]
        
        if not link in link_texts.keys():
            link_texts[link] = []
        link_texts[link].append(text)

# %% [markdown]
# Pick a random regular expression from each regex page

# %%
random.seed(1891014916634710808)

regex_examples = []
for link, texts in link_texts.items():
    regex_examples.append(random.choice(texts))

# %% [markdown]
# CSS examples have already been selected ahead of time in E45 by randomly selecting one properly detected selector from each page where at least one CSS selector was properly detected

# %%
css_examples = [
    '#infolist',
    '#message',
    '#other',
    '#frameDemo',
    '#txt',
    'div:last',
    'iframe[name=iframeTarget]',
    '#result',
    '.window',
    '#my-element',
    'div.foo',
    '#birthday',
    '#input',
    '.myeditable',
    'select.form-control',
    '#nav a',
    '#my-div img',
    '#followercnt',
    '.footable',
    '#submit4',
]

# %% [markdown]
# # Arbiter Function

# %%
def decide(css_score, regex_score):
    return "Regex" if regex_score > css_score else "CSS selector" if css_score > regex_score else "Tie"

# %%
regex_evaluator = RegexAffinityEvaluator()
css_evaluator = CssAffinityEvaluator()

# %%
def display_scores(examples):
    scores = []
    for example in examples:
        css_score = round(css_evaluator.evaluate(example), 2)
        regex_score = round(regex_evaluator.evaluate(example), 2)
        scores.append([
            example,
            css_score,
            regex_score,
            decide(css_score, regex_score)
        ])
    score_frame = pd.DataFrame(scores, columns=["Text", "CSS Affinity", "Regex Affinity", "Class"])
    display(score_frame)

# %% [markdown]
# ## CSS Selectors

# %%
display_scores(css_examples)
# Out:
#                          Text  CSS Affinity  Regex Affinity         Class
# 0                   #infolist          1.00            0.00  CSS selector
# 1                    #message          1.00            0.00  CSS selector
# 2                      #other          1.00            0.00  CSS selector
# 3                  #frameDemo          1.00            0.00  CSS selector
# 4                        #txt          1.00            0.00  CSS selector
# 5                    div:last          0.50            0.00  CSS selector
# 6   iframe[name=iframeTarget]          0.75            0.14  CSS selector
# 7                     #result          1.00            0.00  CSS selector
# 8                     .window          1.00            0.14  CSS selector
# 9                 #my-element          1.00            0.00  CSS selector
# 10                    div.foo          0.75            0.14  CSS selector
# 11                  #birthday          1.00            0.00  CSS selector
# 12                     #input          1.00            0.00  CSS selector
# 13                .myeditable          1.00            0.09  CSS selector
# 14        select.form-control          0.75            0.05  CSS selector
# 15                     #nav a          0.75            0.00  CSS selector
# 16                #my-div img          0.75            0.00  CSS selector
# 17               #followercnt          1.00            0.00  CSS selector
# 18                  .footable          1.00            0.11  CSS selector
# 19                   #submit4          1.00            0.00  CSS selector

# %% [markdown]
# ## Regular expressions

# %%
display_scores(regex_examples)
# Out:
#                                                  Text  CSS Affinity  \
# 0           <username><!\[CDATA\[name\]\]></username>             0
# 1                        (?<=finalNumber=")(.*?)(?=")             0
# 2                                              search             0
# 3   "^[_A-Za-z0-9-\\+]+(\\.[_A-Za-z0-9-]+)*@" + "[...             0
# 4                                           (..)_(..)             0
# 5                     ^[A-Z]{3,9}\ /index\.php\ HTTP/             0
# 6    (<b>) #match opening <b> tag (.*?) #match any...             0
# 7                                                 \\s             0
# 8                                           ^([^/]+)$             0
# 9                                        [^a-zA-Z0-9]             0
# 10                                       ^index\.php$             0
# 11                                     blue|house|car             0
# 12                                     <b>([^<]*)</b>             0
# 13                                               xmas             0
# 14                                     .*\([0-9]*\).*             0
# 15                                        ^old\.html$             0
# 16  ^([\w-\.]+@(?!gmail.com)(?!yahoo.com)(?!hotmai...             0
# 17                                           \|(.*)\|             0
# 18                                          [][${}\\]             0
# 19                                        \(\/[^:]*\)             0
#
#     Regex Affinity  Class
# 0             0.00    Tie
# 1             0.22  Regex
# 2             0.00    Tie
# 3             0.57  Regex
# 4             0.86  Regex
# 5             0.11  Regex
# 6             0.05  Regex
# 7             0.00    Tie
# 8             1.00  Regex
# 9             1.00  Regex
# 10            0.18  Regex
# 11            0.00    Tie
# 12            0.22  Regex
# 13            0.00    Tie
# 14            0.60  Regex
# 15            0.20  Regex
# 16            0.32  Regex
# 17            0.50  Regex
# 18            1.00  Regex
# 19            0.25  Regex
